# %%
print("hello")
# `cmd` + `enter` para executar o bloco do jupyter.
# Out:
# hello

# %%
1+1
# `opt` + `key` para executar o bloco e criar uma nova linha abaixo.
# funciona como output
# Out:
# 2

# %%
a = 1 # declaração de varíaveis
print(a)
# Out:
# 1

# %%
# A variável `a` só vai estar disponível se ela estiver presente no kernel (executada nessa linha, bloco ou em alguma outra)
print(a)
# Out:
# 1

# %% [markdown]
# Jupyter suport o markdown, assim podemos utilizar essa linha. Não executa código python.

# %% [markdown]
# print(a)
